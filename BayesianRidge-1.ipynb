# %%
import pandas as pd
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AI /diamondd.csv')
print(dataset.head())
X = dataset[['carat','depth','table','x','y']]
Y = dataset[['price']]



x = X.values
y = Y.values
print(X)

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.50, random_state=42)

#from sklearn.datasets import load_boston
from sklearn.linear_model import BayesianRidge


blr = BayesianRidge()

blr.fit(x_train, y_train)

predicted=blr.predict(x_test)


print("Predict value " + str(predicted))
print("Real value " + str(y_test))


#print("Accuracy: ",gbr.score(x_test, y_test)*100)

print('r2_score: ',skl.metrics.r2_score(y_test,predicted)*100)
print('explained_variance_score: ',skl.metrics.explained_variance_score(y_test,predicted)*100)
print('mean_gamma_deviance: ',skl.metrics.mean_gamma_deviance(y_test,predicted)*100)
print('mean_absolute_percentage_error',skl.metrics.mean_absolute_percentage_error(y_test,predicted)*100)
# Out:
#    num  carat  depth  table     x     y  price
# 0    1   0.23   61.5   55.0  3.95  3.56   3000
# 1    2   0.21   59.8   61.0  3.89  4.30   3200
# 2    3   0.23   56.9   65.0  4.05  3.80   3450
# 3    4   0.29   62.4   58.0  4.20  3.98   6500
# 4    5   0.31   63.3   58.0  4.34  3.87   3200
#      carat  depth  table     x     y
# 0     0.23   61.5   55.0  3.95  3.56
# 1     0.21   59.8   61.0  3.89  4.30
# 2     0.23   56.9   65.0  4.05  3.80
# 3     0.29   62.4   58.0  4.20  3.98
# 4     0.31   63.3   58.0  4.34  3.87
# ..     ...    ...    ...   ...   ...
# 195   0.70   62.7   59.0  5.67  4.23
# 196   0.70   61.0   57.0  5.73  4.87
# 197   0.70   61.0   58.0  5.78  3.76
# 198   0.70   61.4   57.0  5.76  3.55
# 199   0.72   61.8   61.0  5.82  4.76
#
# [200 rows x 5 columns]
# Predict value [4855.50512369 4855.49911552 4855.49736472 4855.5025096  4855.50029161
#  4855.49516657 4855.49829254 4855.50001283 4855.49747151 4855.49783614
#  4855.49489872 4855.4994609  4855.50466862 4855.49964934 4855.50144314
#  4855.49848198 4855.50421103 4855.50417835 4855.4969631  4855.49849355
#  4855.4957602  4855.49299812 4855.50241778 4855.50034136 4855.49567907
#  4855.49822359 4855.50321257 4855.49618755 4855.50473108 4855.50332551
#  4855.50305677 4855.49430017 4855.50018525 4855.5023306  4855.50349912
#  4855.49940714 4855.50479902 4855.50338767 4855.49878875 4855.49914819
#  4855.49857252 4855.50275584 4855.49986386 4855.50629363 4855.50861736
#  4855.50279486 4855.49674284 4855.49891851 4855.50212219 4855.49798176
#  4855.49912787 4855.49738791 4855.4954651  4855.50078264 4855.49646687
#  4855.49657953 4855.50152017 4855.50372251 4855.51011982 4855.50889512
#  4855.50799758 4855.50616018 4855.49759484 4855.50211021 4855.50128736
#  4855.50541743 4855.49281085 4855.50060676 4855.50032182 4855.50854064
#  4855.49204537 4855.50171919 4855.50503491 4855.49663832 4855.50283893
#  4855.50325767 4855.49610463 4855.49891134 4855.49884222 4855.49945711
#  4855.51000066 4855.49212432 4855.49452714 4855.50185643 4855.49789645
#  4855.49847452 4855.50066742 4855.49705327 4855.50764372 4855.49901822
#  4855.49656279 4855.50115064 4855.49873759 4855.49903173 4855.49414642
#  4855.50121643 4855.50251278 4855.49571928 4855.49674136 4855.49920239]
# Real value [[2697]
#  [5890]
#  [9860]
#  [4876]
#  [1276]
#  [2575]
#  [5690]
#  [7650]
#  [3637]
#  [1480]
#  [3580]
#  [7647]
#  [8470]
#  [1680]
#  [6535]
#  [6353]
#  [2230]
#  [8654]
#  [3890]
#  [2680]
#  [4578]
#  [2380]
#  [4798]
#  [2390]
#  [3690]
#  [3680]
#  [3679]
#  [1270]
#  [2390]
#  [4578]
#  [6780]
#  [4570]
#  [5670]
#  [3780]
#  [4797]
#  [2680]
#  [ 578]
#  [3464]
#  [5798]
#  [2589]
#  [3680]
#  [3685]
#  [3480]
#  [5090]
#  [2376]
#  [4087]
#  [1290]
#  [2390]
#  [3674]
#  [5680]
#  [3578]
#  [3536]
#  [3450]
#  [5690]
#  [4597]
#  [3890]
#  [9753]
#  [1580]
#  [5649]
#  [3480]
#  [8640]
#  [3690]
#  [7850]
#  [3670]
#  [2376]
#  [1298]
#  [3489]
#  [6645]
#  [1290]
#  [6789]
#  [4580]
#  [2390]
#  [8734]
#  [1290]
#  [2568]
#  [5785]
#  [6794]
#  [2577]
#  [3789]
#  [3578]
#  [3450]
#  [3578]
#  [4570]
#  [6435]
#  [3369]
#  [1235]
#  [9657]
#  [3678]
#  [9874]
#  [3570]
#  [8000]
#  [4676]
#  [2690]
#  [2470]
#  [1230]
#  [5785]
#  [9875]
#  [7890]
#  [3970]
#  [3478]]
# r2_score:  -4.056809773098324
# explained_variance_score:  5.7950178600219004e-05
# mean_gamma_deviance:  30.437077636422188
# mean_absolute_percentage_error 72.30393912580143
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
